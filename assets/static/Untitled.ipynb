# %%
import pyvisa as visa

# %%
rm=visa.ResourceManager()

# %%
rm.list_resources()
# Out:
# ('TCPIP0::192.168.0.148::hislip0::INSTR',
#  'TCPIP0::192.168.0.148::inst0::INSTR',
#  'TCPIP0::192.168.0.127::hislip0::INSTR',
#  'TCPIP0::192.168.0.127::inst0::INSTR',
#  'TCPIP0::192.168.0.128::hislip0::INSTR',
#  'TCPIP0::192.168.0.128::inst0::INSTR',
#  'TCPIP0::192.168.0.99::hislip0::INSTR',
#  'TCPIP0::192.168.0.99::inst0::INSTR',
#  'TCPIP0::192.168.0.39::hislip0::INSTR',
#  'TCPIP0::192.168.0.39::inst0::INSTR',
#  'TCPIP0::K-N7745C-00848::inst0::INSTR',
#  'TCPIP0::K-N7745C-00848::hislip0::INSTR',
#  'TCPIP0::K-N7747C-00178::inst0::INSTR',
#  'TCPIP0::K-N7747C-00178::hislip0::INSTR',
#  'TCPIP0::K-N7776C-00272::inst0::INSTR',
#  'TCPIP0::K-N7776C-00272::hislip0::INSTR',
#  'TCPIP0::K-N7776C-00483::inst0::INSTR',
#  'TCPIP0::K-N7776C-00483::hislip0::INSTR',
#  'ASRL3::INSTR',
#  'ASRL10::INSTR')

# %%
Instr128=rm.open_resource('TCPIP0::192.168.0.128::inst0::INSTR')

# %%
Instr128.query('*IDN?')
# Out:
# 'KEYSIGHT TECHNOLOGIES,DSOX1204G,CN58467111,02.12.2021071625\n'
